# %%
import pandas as pd

# %%
df = pd.read_csv('jeopardy.csv')
pd.set_option('display.max_colwidth', 100)
display(df.sample(50))
# Out:
#       Show Number    Air Date             Round                      Category  \
# 3907         5796  2009-11-23         Jeopardy!  STATES THAT END IN HAMPSHIRE
# 2917         1740  1992-03-06   Final Jeopardy!  20th CENTURY VICE PRESIDENTS
# 3789         6144  2011-05-05         Jeopardy!                ALL "AMERICAN"
# 2731         5979  2010-09-16  Double Jeopardy!                    SAY "CHI"s
# 4901         3331  1999-02-15  Double Jeopardy!                 ASIAN NATIONS
# 773          5851  2010-02-08  Double Jeopardy!            FACIAL EXPRESSIONS
# 2754         3815  2001-03-16         Jeopardy!          CELEBRITY RHYME TIME
# 3433         5347  2007-12-04  Double Jeopardy!              HOME, SWEET HOME
# 2965         3697  2000-10-03  Double Jeopardy!                    QUOTATIONS
# 2504         5282  2007-07-24         Jeopardy!                SPORTS LEGENDS
# 5341         5914  2010-05-06         Jeopardy!                SPOILER ALERT!
# ...
