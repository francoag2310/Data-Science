# %%
from selenium import webdriver
import pandas as pd
import time

# %%
PATH = '/Users/francoaguilar/Documents/GitHub/Data-Science/Portfolio/Web Scraping/Selenium/chromedriver'
programs = []
driver = webdriver.Chrome(PATH)
url = 'https://www.mom.gov.sg/passes-and-permits/training-employment-pass/list-of-acceptable-institutions#/?page='

# %%
for i in range(1,16): 
    driver.get(url+ str(i)+ '&q=')

    for table in driver.find_elements_by_xpath('.//*[@id="contentguide_0_documentcontent_0_DivCode"]/div/div/div/table/tbody/tr'):
        data = [item.text for item in table.find_elements_by_xpath(".//*[self::td or self::th or self::tr]")]
        program_info = {
            'Institution': data[0],
            'Country/Region':data[1]
        }
        programs.append(program_info)

print(programs)
# Out:
# [{'Institution': 'Aarhus Universitet (Aarhus University)', 'Country/Region': 'Denmark'}, {'Institution': 'Albert-Ludwigs-Universitat Freiburg im Breisgau', 'Country/Region': 'Germany'}, {'Institution': 'Aoyama Gakuin University', 'Country/Region': 'Japan'}, {'Institution': 'Asian Institute of Management', 'Country/Region': 'Philippines'}, {'Institution': 'Aston University (The University of Aston in Birmingham)', 'Country/Region': 'United Kingdom'}, {'Institution': 'Ateneo de Manila University', 'Country/Region': 'Philippines'}, {'Institution': 'Bangor University (Prifysgol Bangor)[formerly University of Wales, Bangor - 2007]', 'Country/Region': 'United Kingdom'}, {'Institution': 'Bangor University (Prifysgol Bangor)[formerly University of Wales, Bang]', 'Country/Region': 'United Kingdom'}, {'Institution': 'Bayerische Julius-Maximilians Universitat Wurezburg', 'Country/Region': 'Germany'}, {'Institution': 'Beijing Foreign Studies University', 'Country/Region': 'China'}, {'Institution': 'Ben Gurion University of the Negev', 'Country/Region': 'Israel'}, {'Institution': 'Boston College, MA', 'Country/Region': 'United States of America'}, {'Institution': 'Boston University, MA', 'Country/Region': 'United States of America'}, {'Institution': 'Bournemouth University', 'Country/Region': 'United Kingdom'}, {'Institution': 'Brown University, RI', 'Country/Region': 'United States of America'}, {'Institution': 'Brunel University', 'Country/Region': 'United Kingdom'}, {'Institution': 'California Institute of Technology, CA', 'Country/Region': 'United States of America'}, {'Institution': 'Cardiff University (formerly University of Wales, Cardiff, 2004)', 'Country/Region': 'United Kingdom'}, {'Institution': 'Carleton University', 'Country/Region': 'Canada'}, {'Institution': 'Carnegie Mellon University, PA', 'Country/Region': 'United States of America'}, {'Institution': 'Aarhus Universitet (Aarhus University)', 'Country/Region': 'Denmark'}, {'Institution': 'Albert-Ludwigs-Universitat Freiburg im Breisgau', 'Country/Region': 'Germany'}, {'Institution': 'Aoyama Gakuin University', 'Country/Region': 'Japan'}, {'Institution': 'Chinese University of Hong Kong', 'Country/Region': 'Hong KongPhilippines'}, {'Institution': 'Chonbuk/Jeonbug National University, Chonbuk', 'Country/Region': 'KoreaUnited Kingdom'}, {'Institution': 'Christian-Albrechts-Universitat zu Kiel', 'Country/Region': 'GermanyPhilippines'}, {'Institution': 'Chulalongkorn University', 'Country/Region': 'ThailandUnited Kingdom'}, {'Institution': 'Columbia University/ Columbia College, NY', 'Country/Region': 'United States of AmericaUnited Kingdom'}, {'Institution': 'Concordia University', 'Country/Region': 'CanadaGermany'}, {'Institution': 'Dalhousie University', 'Country/Region': 'CanadaChina'}, {'Institution': 'Dalian Maritime University', 'Country/Region': 'ChinaIsrael'}, {'Institution': 'De La Salle University', 'Country/Region': 'PhilippinesUnited States of America'}, {'Institution': 'Deakin University', 'Country/Region': 'AustraliaUnited States of America'}, {'Institution': 'Digipen Institute of Technology', 'Country/Region': 'United States of AmericaUnited Kingdom'}, {'Institution': 'Digipen Institute of Technology (Singapore campus)', 'Country/Region': 'SingaporeUnited States of America'}, {'Institution': 'Director-General of Seacommunications, Indonesia', 'Country/Region': 'IndonesiaUnited Kingdom'}, {'Institution': 'Doshisha University', 'Country/Region': 'JapanUnited States of America'}, {'Institution': 'Duke University, NC', 'Country/Region': 'United States of AmericaUnited Kingdom'}, {'Institution': 'Eberhand-Karls-Universitat Tubingen', 'Country/Region': 'GermanyCanada'}, {'Institution': 'Ecole des Hautes Etudes Commerciales, Jouy-en-Josas (HEC)', 'Country/Region': 'FranceUnited States of America'}, {'Institution': 'Central Queensland University', 'Country/Region': 'AustraliaDenmark'}, {'Institution': 'Chiba University', 'Country/Region': 'JapanGermany'}, {'Institution' ...

# %%
url2 = 'https://www.mom.gov.sg/passes-and-permits/training-employment-pass/list-of-acceptable-institutions#/?page=16&q='

# %%
#df = pd.DataFrame(programs)
#df = df.drop_duplicates(keep='first')
#df.duplicated().sum()
